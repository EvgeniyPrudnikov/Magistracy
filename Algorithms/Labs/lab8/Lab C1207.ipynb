# %% [markdown]
# ## Lab C1207 Prudnikov

# %% [markdown]
# Код программы: https://github.com/EvgeniyPrudnikov/Magistracy/blob/master/Algorithms/Labs/lab8/main.cpp

# %% [markdown]
# ### Подготовка

# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def generate_samples(n,m,rep):
    cmd = './sample {:0} {:1} {:2}'.format(n,m,rep)
    os.system(cmd)

# %%
def plot_hist(filename):
    with open (filename) as f:
        hist_v = list(str.split(f.read()))
    hist_v = map(int,hist_v)
    elems = list(xrange(1,len(hist_v) + 1)) 
    plt.figure(figsize=(13,4))
    plt.ylabel('Number of occurrences')
    plt.xlabel('Stream element')
    plt.grid(True)
    plt.xlim([0,len(elems) + 2])
    width = 1/1
    plt.bar(elems, hist_v, width, color="blue")

# %% [markdown]
# ### Генерация семплов

# %% [markdown]
# Вызываем программу с различными параметрами n m repeat
#
# Для равновероятностных семплов на всех графиках видно, что  количество попаданий i-ого элемента в семпл примерно одинакого для всех элементов, тоесть каждый элемент попадет в семпл с вероятностью 1/n
#
# Для взвешанных семплов на всех графиках видно, что вероятноть попасть в семпл пропорциональна весу элемента, и если вес увеличивается линейно (вес = i), то количество попаданый элемента в семпл также растет линейно, если вес увеличивается квадратично, то количество попаданый элемента в семпл также растет квадратично.

# %% [markdown]
# #### Параметры N = 100; M = 5; Repeat = 3000

# %%
generate_samples(100, 5, 3000)

# %% [markdown]
# ##### Равновероятностный семпл

# %%
plot_hist("hist.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i

# %%
plot_hist("hist_weight_i1.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i*i

# %%
plot_hist("hist_weight_i2.txt")

# %% [markdown]
# #### Параметры N = 100; M = 10; Repeat = 3000

# %%
generate_samples(100, 10, 3000)

# %% [markdown]
# ##### Равновероятностный семпл

# %%
plot_hist("hist.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i

# %%
plot_hist("hist_weight_i1.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i*i

# %%
plot_hist("hist_weight_i2.txt")

# %% [markdown]
# #### Параметры N = 1000; M = 10; Repeat = 3000

# %%
generate_samples(1000, 10, 3000)

# %% [markdown]
# ##### Равновероятностный семпл

# %%
plot_hist("hist.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i

# %%
plot_hist("hist_weight_i1.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i*i

# %%
plot_hist("hist_weight_i2.txt")

# %% [markdown]
# #### Параметры N = 1000; M = 20; Repeat = 3000

# %%
generate_samples(1000, 20, 3000)

# %% [markdown]
# ##### Равновероятностный семпл

# %%
plot_hist("hist.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i

# %%
plot_hist("hist_weight_i1.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i*i

# %%
plot_hist("hist_weight_i2.txt")

# %% [markdown]
# #### Параметры N = 10000; M = 100; Repeat = 3000

# %%
generate_samples(10000, 100, 3000)

# %% [markdown]
# ##### Равновероятностный семпл

# %%
plot_hist("hist.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i

# %%
plot_hist("hist_weight_i1.txt")

# %% [markdown]
# ##### Взвешанный семпл, вес = i*i

# %%
plot_hist("hist_weight_i2.txt")
